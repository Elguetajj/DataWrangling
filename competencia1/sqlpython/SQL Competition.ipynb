# %%
import numpy as np
import pandas as pd
heroes = pd.read_csv("heroes_information.csv")

# %%
###instalar desde anaconda navigator######
from pandasql import *

# %%
pysqldf = lambda q: sqldf(q,globals())

# %%
query2 = " SELECT * FROM heroes limit 10"

# %%
pysqldf(query2)
# Out:
#    id           name  Gender Eye color               Race Hair color  Height  \
# 0   0         A-Bomb    Male    yellow              Human    No Hair   203.0
# 1   1     Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# 2   2       Abin Sur    Male      blue            Ungaran    No Hair   185.0
# 3   3    Abomination    Male     green  Human / Radiation    No Hair   203.0
# 4   4        Abraxas    Male      blue      Cosmic Entity      Black   -99.0
# 5   5  Absorbing Man    Male      blue              Human    No Hair   193.0
# 6   6    Adam Monroe    Male      blue               None      Blond   -99.0
# 7   7   Adam Strange    Male      blue              Human      Blond   185.0
# 8   8       Agent 13  Female      blue               None      Blond   173.0
# 9   9      Agent Bob    Male     brown              Human      Brown   178.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics       None      good   441.0
# ...

# %%
query = "SELECT * FROM heroes"
pysqldf(query)
# Out:
#       id             name  Gender Eye color               Race  \
# 0      0           A-Bomb    Male    yellow              Human
# 1      1       Abe Sapien    Male      blue      Icthyo Sapien
# 2      2         Abin Sur    Male      blue            Ungaran
# 3      3      Abomination    Male     green  Human / Radiation
# 4      4          Abraxas    Male      blue      Cosmic Entity
# ..   ...              ...     ...       ...                ...
# 729  729  Yellowjacket II  Female      blue              Human
# 730  730             Ymir    Male     white        Frost Giant
# 731  731             Yoda    Male     brown     Yoda's species
# 732  732          Zatanna  Female      blue              Human
# 733  733             Zoom    Male       red               None
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# 0             No Hair   203.0      Marvel Comics       None      good   441.0
# ...

# %%
query = "SELECT COUNT(DISTINCT publisher) FROM heroes"
pysqldf(query)
# Out:
#    COUNT(DISTINCT publisher)
# 0                         24

# %%
query = "SELECT count(*) FROM heroes WHERE height > 200 "
pysqldf(query)
# Out:
#    count(*)
# 0        59

# %%
query = "SELECT count(*) FROM heroes WHERE height > 200 and race = 'Human' "
pysqldf(query)
# Out:
#    count(*)
# 0        12

# %%
query = "SELECT count(*) FROM heroes WHERE weight > 100 and weight <200  "
pysqldf(query)
# Out:
#    count(*)
# 0        98

# %%
query = "SELECT count(*) FROM heroes WHERE `Eye color` = 'red' or `Eye color` = 'blue'"
pysqldf(query)
# Out:
#    count(*)
# 0       271

# %%
query = "SELECT count(*) FROM heroes WHERE race = 'human' or (race = 'mutant' and `Hair color`= 'green') or (race = 'vampire' and `Hair color`= 'black')"
pysqldf(query)
# Out:
#    count(*)
# 0         0

# %%
query = "SELECT * FROM heroes ORDER BY race desc"
pysqldf(query)
# Out:
#       id            name  Gender Eye color             Race Hair color  \
# 0    611  Solomon Grundy    Male     black           Zombie      White
# 1    274          Gamora  Female    yellow    Zen-Whoberian      Black
# 2    731            Yoda    Male     brown   Yoda's species      White
# 3    527        Predator    Male      None           Yautja       None
# 4     17           Alien    Male      None  Xenomorph XX121    No Hair
# ..   ...             ...     ...       ...              ...        ...
# 729  723          Wondra  Female      None             None       None
# 730  724  Wyatt Wingfoot    Male     brown             None      Black
# 731  726           X-Man    Male      blue             None      Brown
# 732  727     Yellow Claw    Male      blue             None    No Hair
# 733  733            Zoom    Male       red             None      Brown
#
#      Height          Publisher Skin color Alignment  Weight
# ...

# %%
query = "SELECT gender,count(*) FROM heroes group by gender"
pysqldf(query)
# Out:
#    Gender  count(*)
# 0    None        29
# 1  Female       200
# 2    Male       505

# %%
query = "SELECT publisher,count(*) FROM heroes group by publisher having count(publisher) > 15"
pysqldf(query)
# Out:
#            Publisher  count(*)
# 0          DC Comics       215
# 1  Dark Horse Comics        18
# 2      Marvel Comics       388
# 3       NBC - Heroes        19
